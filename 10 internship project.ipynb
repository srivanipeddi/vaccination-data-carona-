# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file=pd.read_csv('country_vaccinations_by_manufacturer.csv')

# %%
file
# Out:
#              location        date             vaccine  total_vaccinations
# 0           Argentina  12/29/2020             Moderna                   2
# 1           Argentina  12/29/2020  Oxford/AstraZeneca                   3
# 2           Argentina  12/29/2020   Sinopharm/Beijing                   1
# 3           Argentina  12/29/2020           Sputnik V               20481
# 4           Argentina  12/30/2020             Moderna                   2
# ...               ...         ...                 ...                 ...
# 35618  European Union   3/29/2022  Oxford/AstraZeneca            67403106
# 35619  European Union   3/29/2022     Pfizer/BioNTech           600519998
# 35620  European Union   3/29/2022   Sinopharm/Beijing             2301516
# 35621  European Union   3/29/2022             Sinovac                1809
# 35622  European Union   3/29/2022           Sputnik V             1845103
#
# [35623 rows x 4 columns]

# %%
file.isnull().sum()
# Out:
# location              0
# date                  0
# vaccine               0
# total_vaccinations    0
# dtype: int64

# %%
file[file.duplicated()]
# Out:
# Empty DataFrame
# Columns: [location, date, vaccine, total_vaccinations]
# Index: []

# %%
file.drop_duplicates()
# Out:
#              location        date             vaccine  total_vaccinations
# 0           Argentina  12/29/2020             Moderna                   2
# 1           Argentina  12/29/2020  Oxford/AstraZeneca                   3
# 2           Argentina  12/29/2020   Sinopharm/Beijing                   1
# 3           Argentina  12/29/2020           Sputnik V               20481
# 4           Argentina  12/30/2020             Moderna                   2
# ...               ...         ...                 ...                 ...
# 35618  European Union   3/29/2022  Oxford/AstraZeneca            67403106
# 35619  European Union   3/29/2022     Pfizer/BioNTech           600519998
# 35620  European Union   3/29/2022   Sinopharm/Beijing             2301516
# 35621  European Union   3/29/2022             Sinovac                1809
# 35622  European Union   3/29/2022           Sputnik V             1845103
#
# [35623 rows x 4 columns]

# %%
file.head()
# Out:
#     location        date             vaccine  total_vaccinations
# 0  Argentina  12/29/2020             Moderna                   2
# 1  Argentina  12/29/2020  Oxford/AstraZeneca                   3
# 2  Argentina  12/29/2020   Sinopharm/Beijing                   1
# 3  Argentina  12/29/2020           Sputnik V               20481
# 4  Argentina  12/30/2020             Moderna                   2

# %%
file.tail()
# Out:
#              location       date             vaccine  total_vaccinations
# 35618  European Union  3/29/2022  Oxford/AstraZeneca            67403106
# 35619  European Union  3/29/2022     Pfizer/BioNTech           600519998
# 35620  European Union  3/29/2022   Sinopharm/Beijing             2301516
# 35621  European Union  3/29/2022             Sinovac                1809
# 35622  European Union  3/29/2022           Sputnik V             1845103

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35623 entries, 0 to 35622
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   location            35623 non-null  object
#  1   date                35623 non-null  object
#  2   vaccine             35623 non-null  object
#  3   total_vaccinations  35623 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 1.1+ MB

# %%
file.nlargest(5,'total_vaccinations')
# Out:
#              location       date          vaccine  total_vaccinations
# 35619  European Union  3/29/2022  Pfizer/BioNTech           600519998
# 35610  European Union  3/28/2022  Pfizer/BioNTech           600442246
# 35601  European Union  3/27/2022  Pfizer/BioNTech           600350217
# 35592  European Union  3/26/2022  Pfizer/BioNTech           600329480
# 35583  European Union  3/25/2022  Pfizer/BioNTech           600245781

# %%
file.nsmallest(5,'total_vaccinations')
# Out:
#      location       date             vaccine  total_vaccinations
# 2630  Austria   1/8/2021             Moderna                   0
# 2631  Austria   1/8/2021             Novavax                   0
# 2632  Austria   1/8/2021  Oxford/AstraZeneca                   0
# 2636  Austria  1/15/2021             Novavax                   0
# 2637  Austria  1/15/2021  Oxford/AstraZeneca                   0

# %%
file.nunique()
# Out:
# location                 43
# date                    473
# vaccine                  10
# total_vaccinations    29210
# dtype: int64

# %%
file['location'].unique()
# Out:
# array(['Argentina', 'Austria', 'Belgium', 'Bulgaria', 'Chile', 'Croatia',
#        'Cyprus', 'Czechia', 'Denmark', 'Ecuador', 'Estonia', 'Finland',
#        'France', 'Germany', 'Hong Kong', 'Hungary', 'Iceland', 'Ireland',
#        'Italy', 'Japan', 'Latvia', 'Liechtenstein', 'Lithuania',
#        'Luxembourg', 'Malta', 'Nepal', 'Netherlands', 'Norway', 'Peru',
#        'Poland', 'Portugal', 'Romania', 'Slovakia', 'Slovenia',
#        'South Africa', 'South Korea', 'Spain', 'Sweden', 'Switzerland',
#        'Ukraine', 'United States', 'Uruguay', 'European Union'],
#       dtype=object)

# %%
plt.figure(figsize=(22,5))
file.boxplot()
# Out:
# <AxesSubplot:>

# %%
f1=file[file['total_vaccinations']<16]
f1.boxplot('total_vaccinations')
# Out:
# <AxesSubplot:>

# %%
file
# Out:
#              location        date             vaccine  total_vaccinations
# 0           Argentina  12/29/2020             Moderna                   2
# 1           Argentina  12/29/2020  Oxford/AstraZeneca                   3
# 2           Argentina  12/29/2020   Sinopharm/Beijing                   1
# 3           Argentina  12/29/2020           Sputnik V               20481
# 4           Argentina  12/30/2020             Moderna                   2
# ...               ...         ...                 ...                 ...
# 35618  European Union   3/29/2022  Oxford/AstraZeneca            67403106
# 35619  European Union   3/29/2022     Pfizer/BioNTech           600519998
# 35620  European Union   3/29/2022   Sinopharm/Beijing             2301516
# 35621  European Union   3/29/2022             Sinovac                1809
# 35622  European Union   3/29/2022           Sputnik V             1845103
#
# [35623 rows x 4 columns]

# %%
plt.figure(figsize=(22,7))
sns.heatmap(file.corr(),cmap='rainbow',annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.rcParams['figure.figsize']=[20,6]
file.nlargest(100,"total_vaccinations").plot(kind="bar",x="location",y="total_vaccinations",color="c",grid="True")
# Out:
# <AxesSubplot:xlabel='location'>

# %%
plt.rcParams['figure.figsize']=[20,6]
file.nsmallest(100,"total_vaccinations").plot(kind="bar",x="location",y="total_vaccinations",color="g")
# Out:
# <AxesSubplot:xlabel='location'>

# %%
plt.rcParams['figure.figsize']=[20,6]
file.nsmallest(100,"total_vaccinations").plot(kind="bar",x="vaccine",y="total_vaccinations",color="g")
# Out:
# <AxesSubplot:xlabel='vaccine'>

# %%
plt.rcParams['figure.figsize']=[20,6]
file.nlargest(100,"total_vaccinations").plot(kind="bar",x="vaccine",y="total_vaccinations",color="g")
# Out:
# <AxesSubplot:xlabel='vaccine'>

# %%
plt.figure(figsize=(22,5))
sns.set_context('poster',font_scale=(0.7))
plt.xticks(rotation=80)
sns.barplot(x='location',y='total_vaccinations',data=file)
# Out:
# <AxesSubplot:xlabel='location', ylabel='total_vaccinations'>

# %%
plt.figure(figsize=(22,5))
sns.set_context('poster',font_scale=(0.7))
plt.xticks(rotation=80)
sns.barplot(x='vaccine',y='total_vaccinations',data=file)
# Out:
# <AxesSubplot:xlabel='vaccine', ylabel='total_vaccinations'>

# %%
sns.distplot(file['total_vaccinations'],color='c',bins=20)
# Out:
# C:\Users\sriva\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_vaccinations', ylabel='Density'>

# %%
sns.displot(file['total_vaccinations'],color='c',bins=20)

# %%
plt.figure(figsize=(22,5))
sns.set_context('poster',font_scale=(0.7))
plt.xticks(rotation=80)
sns.countplot('vaccine',data=file)
# Out:
# C:\Users\sriva\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='vaccine', ylabel='count'>

# %%
plt.figure(figsize=(22,5))
sns.set_context('poster',font_scale=(0.7))
plt.xticks(rotation=80)
sns.countplot('location',data=file)
# Out:
# C:\Users\sriva\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='location', ylabel='count'>

# %%
plt.figure(figsize=(22,5))
sns.set_context('poster',font_scale=(0.7))
plt.xticks(rotation=80)
sns.barplot(x='location',y='total_vaccinations',hue='vaccine',data=file)
# Out:
# <AxesSubplot:xlabel='location', ylabel='total_vaccinations'>

# %% [markdown]
# # vaccine groupby

# %%
f1=file.groupby('vaccine').mean()

# %%
f1
# Out:
#                     total_vaccinations
# vaccine
# CanSino                   3.035768e+05
# Covaxin                   7.616205e+00
# Johnson&Johnson           2.287156e+06
# Moderna                   1.552058e+07
# Novavax                   4.886592e+03
# Oxford/AstraZeneca        7.003092e+06
# Pfizer/BioNTech           3.879792e+07
# Sinopharm/Beijing         7.241682e+06
# Sinovac                   5.556222e+06
# Sputnik V                 5.923586e+06

# %%
plt.figure(figsize=(15,5))
f1.plot(kind='bar',y='total_vaccinations')
# Out:
# <AxesSubplot:xlabel='vaccine'>

# %%
f1.plot(kind='pie',y='total_vaccinations',autopct='%.2f',legend=False)
# Out:
# <AxesSubplot:ylabel='total_vaccinations'>

# %% [markdown]
# # location groupby

# %%
f2=file.groupby('location').mean()

# %%
f2
# Out:
#                 total_vaccinations
# location
# Argentina             7.104964e+06
# Austria               1.864109e+06
# Belgium               2.607487e+06
# Bulgaria              5.712269e+05
# Chile                 6.652215e+06
# Croatia               7.218735e+05
# Cyprus                2.394061e+05
# Czechia               2.471389e+06
# Denmark               1.615632e+06
# Ecuador               3.598674e+06
# Estonia               2.971509e+05
# European Union        4.682682e+07
# Finland               1.438115e+06
# France                1.947763e+07
# Germany               1.702307e+07
# Hong Kong             3.424323e+06
# Hungary               1.744284e+06
# Iceland               1.500218e+04
# Ireland               1.419179e+06
# Italy                 1.727065e+07
# Japan                 1.737966e+07
# Latvia                3.582511e+05
# Liechtenstein         1.216433e+04
# Lithuania             6.658815e+05
# Luxembourg            1.544932e+05
# ...

# %%
plt.figure(figsize=(15,5))
f2.plot(kind='bar',y='total_vaccinations')
# Out:
# <AxesSubplot:xlabel='location'>

# %%
f1=file[file['vaccine']=="Moderna"]

# %%
f1
# Out:
#              location        date  vaccine  total_vaccinations
# 0           Argentina  12/29/2020  Moderna                   2
# 4           Argentina  12/30/2020  Moderna                   2
# 8           Argentina  12/31/2020  Moderna                   2
# 12          Argentina    1/1/2021  Moderna                   2
# 16          Argentina    1/2/2021  Moderna                   2
# ...               ...         ...      ...                 ...
# 35580  European Union   3/25/2022  Moderna           145274257
# 35589  European Union   3/26/2022  Moderna           145292092
# 35598  European Union   3/27/2022  Moderna           145297121
# 35607  European Union   3/28/2022  Moderna           145315722
# 35616  European Union   3/29/2022  Moderna           145331851
#
# [6641 rows x 4 columns]
